# %%
import numpy as np
import math
from models import interpolation , SRCNN_train , SRCNN_model, SRCNN_predict , DNCNN_train , DNCNN_model , DNCNN_predict
#from scipy.misc import imresize
from scipy.io import loadmat
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.
# C:\Users\mferrero\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\mferrero\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\mferrero\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\mferrero\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\mferrero\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\mferrero\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\mferrero\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\mferrero\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\mferrero\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\mferrero\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\mferrero\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\mferrero\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
if __name__ == "__main__":
    # load datasets 
    channel_model = "VehA"
    SNR = 22
    Number_of_pilots = 48
    perfect = loadmat("Perfect_"+ channel_model + ".mat")['My_perfect_H']
    noisy_input = loadmat("Noisy_" + channel_model + "_" + "SNR_" + str(SNR) + ".mat")['My_noisy_H']             

    interp_noisy = interpolation(noisy_input , SNR , Number_of_pilots , 'rbf')
    
    #interp_noisy = numpy.load('drive/codes/my_srcnn/SUI5_12_48_rbf.npy')
    #perfect = loadmat('drive/codes/my_srcnn/SUI5_perfect.mat')['SUI5_perfect_H']
    perfect_image = np.zeros((len(perfect),72,14,2))
    perfect_image[:,:,:,0] = np.real(perfect)
    perfect_image[:,:,:,1] = np.imag(perfect)
    perfect_image = np.concatenate((perfect_image[:,:,:,0], perfect_image[:,:,:,1]), axis=0).reshape(2*len(perfect), 72, 14, 1)
    
    ####### ------ training SRCNN ------ #######
    idx_random = np.random.rand(len(perfect_image)) < (1/9)  # uses 32000 from 36000 as training and the rest as validation
    train_data, train_label = interp_noisy[idx_random,:,:,:] , perfect_image[idx_random,:,:,:]
    val_data, val_label = interp_noisy[~idx_random,:,:,:] , perfect_image[~idx_random,:,:,:]    
    SRCNN_train(train_data ,train_label, val_data , val_label , channel_model , Number_of_pilots , SNR )
    
    ####### ------ prediction using SRCNN ------ #######
    srcnn_pred_train = SRCNN_predict(train_data, channel_model , Number_of_pilots , SNR)
    srcnn_pred_validation = SRCNN_predict(train_data, channel_model , Number_of_pilots , SNR)
	
    ####### ------ training DNCNN ------ #######
    DNCNN_train(train_data, train_label, val_data , val_label, channel_model , Number_of_pilots , SNR)
# Out:
# C:\Users\mferrero\Desktop\Mestrado_2020\TP555\Artigos\Opções_Projeto_Final\ChannelNet-master\ChannelNet-master\models.py:90: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (9, 9), activation="relu", padding="same", kernel_initializer="he_normal")`
#   c1 = Convolution2D( 64 , 9 , 9 , activation = 'relu', init = 'he_normal', border_mode='same')(x)
# C:\Users\mferrero\Desktop\Mestrado_2020\TP555\Artigos\Opções_Projeto_Final\ChannelNet-master\ChannelNet-master\models.py:91: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), activation="relu", padding="same", kernel_initializer="he_normal")`
#   c2 = Convolution2D( 32 , 1 , 1 , activation = 'relu', init = 'he_normal', border_mode='same')(c1)
# C:\Users\mferrero\Desktop\Mestrado_2020\TP555\Artigos\Opções_Projeto_Final\ChannelNet-master\ChannelNet-master\models.py:92: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (5, 5), padding="same", kernel_initializer="he_normal")`
#   c3 = Convolution2D( 1 , 5 , 5 , init = 'he_normal', border_mode='same')(c2)
# C:\Users\mferrero\Desktop\Mestrado_2020\TP555\Artigos\Opções_Projeto_Final\ChannelNet-master\ChannelNet-master\models.py:94: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("co...)`
#   model = Model(input = x, output = c3)
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 72, 14, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 14, 64)        5248
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 72, 14, 32)        2080
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 72, 14, 1)         801
# =================================================================
# Total params: 8,129
# Trainable params: 8,129
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:From C:\Users\mferrero\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
#
# Epoch 00001: val_loss improved from inf to 0.01120, saving model to SRCNN_check.h5
#
# Epoch 00002: val_loss improved from 0.01120 to 0.00536, saving model to SRCNN_check.h5
#
# Epoch 00003: val_loss improved from 0.00536 to 0.00376, saving model to SRCNN_check.h5
#
# Epoch 00004: val_loss improved from 0.00376 to 0.00322, saving model to SRCNN_check.h5
#
# Epoch 00005: val_loss improved from 0.00322 to 0.00295, saving model to SRCNN_check.h5
#
# Epoch 00006: val_loss improved from 0.00295 to 0.00273, saving model to SRCNN_check.h5
#
# Epoch 00007: val_loss improved from 0.00273 to 0.00259, saving model to SRCNN_check.h5
#
# Epoch 00008: val_loss improved from 0.00259 to 0.00245, saving model to SRCNN_check.h5
#
# Epoch 00009: val_loss improved from 0.00245 to 0.00236, saving model to SRCNN_check.h5
#
# Epoch 00010: val_loss improved from 0.00236 to 0.00228, saving model to SRCNN_check.h5
#
# Epoch 00011: val_loss improved from 0.00228 to 0.00222, saving model to SRCNN_check.h5
#
# Epoch 00012: val_loss improved from 0.00222 to 0.00215, saving model to SRCNN_check.h5
#
# Epoch 00013: val_loss did not improve from 0.00215
#
# Epoch 00014: val_loss improved from 0.00215 to 0.00208, saving model to SRCNN_check.h5
#
# Epoch 00015: val_loss improved from 0.00208 to 0.00205, saving model to SRCNN_check.h5
#
# Epoch 00016: val_loss improved from 0.00205 to 0.00198, saving model to SRCNN_check.h5
#
# Epoch 00017: val_loss did not improve from 0.00198
#
# Epoch 00018: val_loss did not improve from 0.00198
#
# Epoch 00019: val_loss improved from 0.00198 to 0.00189, saving model to SRCNN_check.h5
#
# Epoch 00020: val_loss did not improve from 0.00189
#
# Epoch 00021: val_loss improved from 0.00189 to 0.00186, saving model to SRCNN_check.h5
#
# Epoch 00022: val_loss improved from 0.00186 to 0.00183, saving model to SRCNN_check.h5
#
# Epoch 00023: val_loss did not improve from 0.00183
#
# Epoch 00024: val_loss did not improve from 0.00183
#
# Epoch 00025: val_loss did not improve from 0.00183
#
# Epoch 00026: val_loss did not improve from 0.00183
#
# Epoch 00027: val_loss improved from 0.00183 to 0.00179, saving model to SRCNN_check.h5
#
# Epoch 00028: val_loss improved from 0.00179 to 0.00177, saving model to SRCNN_check.h5
#
# Epoch 00029: val_loss did not improve from 0.00177
#
# Epoch 00030: val_loss improved from 0.00177 to 0.00172, saving model to SRCNN_check.h5
#
# Epoch 00031: val_loss did not improve from 0.00172
#
# Epoch 00032: val_loss did not improve from 0.00172
#
# Epoch 00033: val_loss did not improve from 0.00172
#
# Epoch 00034: val_loss did not improve from 0.00172
#
# Epoch 00035: val_loss did not improve from 0.00172
#
# Epoch 00036: val_loss did not improve from 0.00172
#
# Epoch 00037: val_loss improved from 0.00172 to 0.00169, saving model to SRCNN_check.h5
#
# Epoch 00038: val_loss did not improve from 0.00169
#
# Epoch 00039: val_loss improved from 0.00169 to 0.00166, saving model to SRCNN_check.h5
#
# Epoch 00040: val_loss improved from 0.00166 to 0.00163, saving model to SRCNN_check.h5
#
# Epoch 00041: val_loss improved from 0.00163 to 0.00163, saving model to SRCNN_check.h5
#
# Epoch 00042: val_loss did not improve from 0.00163
#
# Epoch 00043: val_loss did not improve from 0.00163
#
# Epoch 00044: val_loss did not improve from 0.00163
#
# Epoch 00045: val_loss did not improve from 0.00163
#
# Epoch 00046: val_loss did not improve from 0.00163
#
# Epoch 00047: val_loss did not improve from 0.00163
#
# Epoch 00048: val_loss did not improve from 0.00163
#
# Epoch 00049: val_loss did not improve from 0.00163
#
# Epoch 00050: val_loss improved from 0.00163 to 0.00158, saving model to SRCNN_check.h5
#
# Epoch 00051: val_loss did not improve from 0.00158
#
# Epoch 00052: val_loss did not improve from 0.00158
#
# Epoch 00053: val_loss did not improve from 0.00158
#
# Epoch 00054: val_loss did not improve from 0.00158
#
# Epoch 00055: val_loss improved from 0.00158 to 0.00155, saving model to SRCNN_check.h5
#
# Epoch 00056: val_loss did not improve from 0.00155
#
# Epoch 00057: val_loss improved from 0.00155 to 0.00155, saving model to SRCNN_check.h5
#
# Epoch 00058: val_loss improved from 0.00155 to 0.00155, saving model to SRCNN_check.h5
#
# Epoch 00059: val_loss did not improve from 0.00155
#
# Epoch 00060: val_loss did not improve from 0.00155
#
# Epoch 00061: val_loss did not improve from 0.00155
#
# Epoch 00062: val_loss did not improve from 0.00155
#
# Epoch 00063: val_loss improved from 0.00155 to 0.00154, saving model to SRCNN_check.h5
#
# Epoch 00064: val_loss did not improve from 0.00154
#
# Epoch 00065: val_loss improved from 0.00154 to 0.00152, saving model to SRCNN_check.h5
#
# Epoch 00066: val_loss did not improve from 0.00152
#
# Epoch 00067: val_loss did not improve from 0.00152
#
# Epoch 00068: val_loss improved from 0.00152 to 0.00151, saving model to SRCNN_check.h5
#
# Epoch 00069: val_loss did not improve from 0.00151
#
# Epoch 00070: val_loss did not improve from 0.00151
#
# Epoch 00071: val_loss did not improve from 0.00151
#
# Epoch 00072: val_loss did not improve from 0.00151
#
# Epoch 00073: val_loss did not improve from 0.00151
#
# Epoch 00074: val_loss did not improve from 0.00151
#
# Epoch 00075: val_loss did not improve from 0.00151
#
# Epoch 00076: val_loss did not improve from 0.00151
#
# Epoch 00077: val_loss did not improve from 0.00151
#
# Epoch 00078: val_loss improved from 0.00151 to 0.00150, saving model to SRCNN_check.h5
#
# Epoch 00079: val_loss improved from 0.00150 to 0.00150, saving model to SRCNN_check.h5
#
# Epoch 00080: val_loss did not improve from 0.00150
#
# Epoch 00081: val_loss improved from 0.00150 to 0.00149, saving model to SRCNN_check.h5
#
# Epoch 00082: val_loss did not improve from 0.00149
#
# Epoch 00083: val_loss did not improve from 0.00149
#
# Epoch 00084: val_loss did not improve from 0.00149
#
# Epoch 00085: val_loss did not improve from 0.00149
#
# Epoch 00086: val_loss improved from 0.00149 to 0.00148, saving model to SRCNN_check.h5
#
# Epoch 00087: val_loss did not improve from 0.00148
#
# Epoch 00088: val_loss did not improve from 0.00148
#
# Epoch 00089: val_loss did not improve from 0.00148
#
# Epoch 00090: val_loss improved from 0.00148 to 0.00147, saving model to SRCNN_check.h5
#
# Epoch 00091: val_loss did not improve from 0.00147
#
# Epoch 00092: val_loss improved from 0.00147 to 0.00147, saving model to SRCNN_check.h5
#
# Epoch 00093: val_loss did not improve from 0.00147
#
# Epoch 00094: val_loss improved from 0.00147 to 0.00146, saving model to SRCNN_check.h5
#
# Epoch 00095: val_loss did not improve from 0.00146
#
# Epoch 00096: val_loss did not improve from 0.00146
#
# Epoch 00097: val_loss did not improve from 0.00146
#
# Epoch 00098: val_loss did not improve from 0.00146
#
# Epoch 00099: val_loss did not improve from 0.00146
#
# Epoch 00100: val_loss did not improve from 0.00146
#
# Epoch 00101: val_loss did not improve from 0.00146
#
# Epoch 00102: val_loss improved from 0.00146 to 0.00144, saving model to SRCNN_check.h5
#
# Epoch 00103: val_loss did not improve from 0.00144
#
# Epoch 00104: val_loss did not improve from 0.00144
#
# Epoch 00105: val_loss did not improve from 0.00144
#
# Epoch 00106: val_loss did not improve from 0.00144
#
# Epoch 00107: val_loss improved from 0.00144 to 0.00144, saving model to SRCNN_check.h5
#
# Epoch 00108: val_loss did not improve from 0.00144
#
# Epoch 00109: val_loss did not improve from 0.00144
# Epoch 00110: val_loss did not improve from 0.00144
#
# Epoch 00111: val_loss did not improve from 0.00144
#
# Epoch 00112: val_loss did not improve from 0.00144
#
# Epoch 00113: val_loss did not improve from 0.00144
#
# Epoch 00114: val_loss did not improve from 0.00144
#
# Epoch 00115: val_loss did not improve from 0.00144
#
# Epoch 00116: val_loss did not improve from 0.00144
#
# Epoch 00117: val_loss improved from 0.00144 to 0.00143, saving model to SRCNN_check.h5
#
# Epoch 00118: val_loss did not improve from 0.00143
#
# Epoch 00119: val_loss did not improve from 0.00143
#
# Epoch 00120: val_loss did not improve from 0.00143
#
# Epoch 00121: val_loss did not improve from 0.00143
#
# Epoch 00122: val_loss did not improve from 0.00143
#
# Epoch 00123: val_loss did not improve from 0.00143
#
# Epoch 00124: val_loss did not improve from 0.00143
#
# Epoch 00125: val_loss did not improve from 0.00143
#
# Epoch 00126: val_loss did not improve from 0.00143
#
# Epoch 00127: val_loss did not improve from 0.00143
#
# Epoch 00128: val_loss did not improve from 0.00143
#
# Epoch 00129: val_loss did not improve from 0.00143
#
# Epoch 00130: val_loss did not improve from 0.00143
#
# Epoch 00131: val_loss did not improve from 0.00143
#
# Epoch 00132: val_loss did not improve from 0.00143
#
# Epoch 00133: val_loss did not improve from 0.00143
#
# Epoch 00134: val_loss improved from 0.00143 to 0.00142, saving model to SRCNN_check.h5
#
# Epoch 00135: val_loss did not improve from 0.00142
#
# Epoch 00136: val_loss improved from 0.00142 to 0.00140, saving model to SRCNN_check.h5
#
# Epoch 00137: val_loss did not improve from 0.00140
#
# Epoch 00138: val_loss did not improve from 0.00140
#
# Epoch 00139: val_loss did not improve from 0.00140
#
# Epoch 00140: val_loss did not improve from 0.00140
#
# Epoch 00141: val_loss did not improve from 0.00140
#
# Epoch 00142: val_loss did not improve from 0.00140
#
# Epoch 00143: val_loss did not improve from 0.00140
#
# Epoch 00144: val_loss did not improve from 0.00140
#
# Epoch 00145: val_loss did not improve from 0.00140
#
# Epoch 00146: val_loss improved from 0.00140 to 0.00139, saving model to SRCNN_check.h5
#
# Epoch 00147: val_loss did not improve from 0.00139
#
# Epoch 00148: val_loss did not improve from 0.00139
#
# Epoch 00149: val_loss did not improve from 0.00139
#
# Epoch 00150: val_loss did not improve from 0.00139
#
# Epoch 00151: val_loss did not improve from 0.00139
#
# Epoch 00152: val_loss did not improve from 0.00139
#
# Epoch 00153: val_loss did not improve from 0.00139
#
# Epoch 00154: val_loss did not improve from 0.00139
#
# Epoch 00155: val_loss did not improve from 0.00139
#
# Epoch 00156: val_loss did not improve from 0.00139
#
# Epoch 00157: val_loss did not improve from 0.00139
#
# Epoch 00158: val_loss did not improve from 0.00139
#
# Epoch 00159: val_loss did not improve from 0.00139
#
# Epoch 00160: val_loss did not improve from 0.00139
#
# Epoch 00161: val_loss did not improve from 0.00139
#
# Epoch 00162: val_loss did not improve from 0.00139
#
# Epoch 00163: val_loss did not improve from 0.00139
#
# Epoch 00164: val_loss improved from 0.00139 to 0.00138, saving model to SRCNN_check.h5
#
# Epoch 00165: val_loss did not improve from 0.00138
#
# Epoch 00166: val_loss did not improve from 0.00138
#
# Epoch 00167: val_loss did not improve from 0.00138
#
# Epoch 00168: val_loss did not improve from 0.00138
#
# Epoch 00169: val_loss did not improve from 0.00138
#
# Epoch 00170: val_loss did not improve from 0.00138
#
# Epoch 00171: val_loss did not improve from 0.00138
#
# Epoch 00172: val_loss did not improve from 0.00138
#
# Epoch 00173: val_loss improved from 0.00138 to 0.00138, saving model to SRCNN_check.h5
#
# Epoch 00174: val_loss did not improve from 0.00138
#
# Epoch 00175: val_loss did not improve from 0.00138
#
# Epoch 00176: val_loss did not improve from 0.00138
#
# Epoch 00177: val_loss did not improve from 0.00138
#
# Epoch 00178: val_loss did not improve from 0.00138
#
# Epoch 00179: val_loss did not improve from 0.00138
#
# Epoch 00180: val_loss improved from 0.00138 to 0.00137, saving model to SRCNN_check.h5
#
# Epoch 00181: val_loss did not improve from 0.00137
#
# Epoch 00182: val_loss did not improve from 0.00137
#
# Epoch 00183: val_loss did not improve from 0.00137
#
# Epoch 00184: val_loss did not improve from 0.00137
#
# Epoch 00185: val_loss did not improve from 0.00137
#
# Epoch 00186: val_loss did not improve from 0.00137
#
# Epoch 00187: val_loss improved from 0.00137 to 0.00136, saving model to SRCNN_check.h5
#
# Epoch 00188: val_loss did not improve from 0.00136
#
# Epoch 00189: val_loss did not improve from 0.00136
#
# Epoch 00190: val_loss did not improve from 0.00136
#
# Epoch 00191: val_loss did not improve from 0.00136
#
# Epoch 00192: val_loss did not improve from 0.00136
#
# Epoch 00193: val_loss did not improve from 0.00136
#
# Epoch 00194: val_loss did not improve from 0.00136
#
# Epoch 00195: val_loss did not improve from 0.00136
#
# Epoch 00196: val_loss did not improve from 0.00136
#
# Epoch 00197: val_loss did not improve from 0.00136
#
# Epoch 00198: val_loss did not improve from 0.00136
#
# Epoch 00199: val_loss did not improve from 0.00136
#
# Epoch 00200: val_loss did not improve from 0.00136
#
# Epoch 00201: val_loss did not improve from 0.00136
#
# Epoch 00202: val_loss did not improve from 0.00136
#
# Epoch 00203: val_loss did not improve from 0.00136
#
# Epoch 00204: val_loss did not improve from 0.00136
#
# Epoch 00205: val_loss did not improve from 0.00136
#
# Epoch 00206: val_loss did not improve from 0.00136
#
# Epoch 00207: val_loss improved from 0.00136 to 0.00136, saving model to SRCNN_check.h5
#
# Epoch 00208: val_loss did not improve from 0.00136
#
# Epoch 00209: val_loss did not improve from 0.00136
#
# Epoch 00210: val_loss did not improve from 0.00136
#
# Epoch 00211: val_loss did not improve from 0.00136
#
# Epoch 00212: val_loss did not improve from 0.00136
#
# Epoch 00213: val_loss did not improve from 0.00136
#
# Epoch 00214: val_loss did not improve from 0.00136
#
# Epoch 00215: val_loss did not improve from 0.00136
#
# Epoch 00216: val_loss improved from 0.00136 to 0.00135, saving model to SRCNN_check.h5
#
# Epoch 00217: val_loss improved from 0.00135 to 0.00135, saving model to SRCNN_check.h5
#
# Epoch 00218: val_loss improved from 0.00135 to 0.00134, saving model to SRCNN_check.h5
#
# Epoch 00219: val_loss did not improve from 0.00134
#
# Epoch 00220: val_loss did not improve from 0.00134
#
# Epoch 00221: val_loss did not improve from 0.00134
#
# Epoch 00222: val_loss did not improve from 0.00134
#
# Epoch 00223: val_loss did not improve from 0.00134
#
# Epoch 00224: val_loss did not improve from 0.00134
#
# Epoch 00225: val_loss did not improve from 0.00134
#
# Epoch 00226: val_loss did not improve from 0.00134
#
# Epoch 00227: val_loss did not improve from 0.00134
#
# Epoch 00228: val_loss did not improve from 0.00134
#
# Epoch 00229: val_loss did not improve from 0.00134
#
# Epoch 00230: val_loss did not improve from 0.00134
#
# Epoch 00231: val_loss did not improve from 0.00134
#
# Epoch 00232: val_loss did not improve from 0.00134
#
# Epoch 00233: val_loss did not improve from 0.00134
#
# Epoch 00234: val_loss did not improve from 0.00134
#
# Epoch 00235: val_loss did not improve from 0.00134
#
# Epoch 00236: val_loss did not improve from 0.00134
#
# Epoch 00237: val_loss did not improve from 0.00134
#
# Epoch 00238: val_loss did not improve from 0.00134
#
# Epoch 00239: val_loss did not improve from 0.00134
#
# Epoch 00240: val_loss did not improve from 0.00134
#
# Epoch 00241: val_loss did not improve from 0.00134
#
# Epoch 00242: val_loss did not improve from 0.00134
#
# Epoch 00243: val_loss did not improve from 0.00134
#
# Epoch 00244: val_loss did not improve from 0.00134
#
# Epoch 00245: val_loss did not improve from 0.00134
#
# Epoch 00246: val_loss improved from 0.00134 to 0.00134, saving model to SRCNN_check.h5
#
# Epoch 00247: val_loss did not improve from 0.00134
#
# Epoch 00248: val_loss did not improve from 0.00134
#
# Epoch 00249: val_loss did not improve from 0.00134
#
# Epoch 00250: val_loss did not improve from 0.00134
#
# Epoch 00251: val_loss did not improve from 0.00134
#
# Epoch 00252: val_loss did not improve from 0.00134
#
# Epoch 00253: val_loss did not improve from 0.00134
#
# Epoch 00254: val_loss did not improve from 0.00134
#
# Epoch 00255: val_loss improved from 0.00134 to 0.00134, saving model to SRCNN_check.h5
#
# Epoch 00256: val_loss did not improve from 0.00134
#
# Epoch 00257: val_loss did not improve from 0.00134
# Epoch 00258: val_loss did not improve from 0.00134
#
# Epoch 00259: val_loss improved from 0.00134 to 0.00133, saving model to SRCNN_check.h5
#
# Epoch 00260: val_loss did not improve from 0.00133
#
# Epoch 00261: val_loss did not improve from 0.00133
#
# Epoch 00262: val_loss did not improve from 0.00133
#
# Epoch 00263: val_loss did not improve from 0.00133
#
# Epoch 00264: val_loss did not improve from 0.00133
#
# Epoch 00265: val_loss did not improve from 0.00133
#
# Epoch 00266: val_loss did not improve from 0.00133
#
# Epoch 00267: val_loss did not improve from 0.00133
#
# Epoch 00268: val_loss did not improve from 0.00133
#
# Epoch 00269: val_loss did not improve from 0.00133
#
# Epoch 00270: val_loss improved from 0.00133 to 0.00133, saving model to SRCNN_check.h5
#
# Epoch 00271: val_loss did not improve from 0.00133
#
# Epoch 00272: val_loss did not improve from 0.00133
#
# Epoch 00273: val_loss did not improve from 0.00133
#
# Epoch 00274: val_loss did not improve from 0.00133
#
# Epoch 00275: val_loss did not improve from 0.00133
#
# Epoch 00276: val_loss improved from 0.00133 to 0.00132, saving model to SRCNN_check.h5
#
# Epoch 00277: val_loss did not improve from 0.00132
#
# Epoch 00278: val_loss did not improve from 0.00132
#
# Epoch 00279: val_loss did not improve from 0.00132
#
# Epoch 00280: val_loss did not improve from 0.00132
#
# Epoch 00281: val_loss did not improve from 0.00132
#
# Epoch 00282: val_loss did not improve from 0.00132
#
# Epoch 00283: val_loss did not improve from 0.00132
#
# Epoch 00284: val_loss did not improve from 0.00132
#
# Epoch 00285: val_loss did not improve from 0.00132
#
# Epoch 00286: val_loss did not improve from 0.00132
#
# Epoch 00287: val_loss did not improve from 0.00132
#
# Epoch 00288: val_loss did not improve from 0.00132
#
# Epoch 00289: val_loss did not improve from 0.00132
#
# Epoch 00290: val_loss did not improve from 0.00132
#
# Epoch 00291: val_loss did not improve from 0.00132
#
# Epoch 00292: val_loss did not improve from 0.00132
#
# Epoch 00293: val_loss did not improve from 0.00132
#
# Epoch 00294: val_loss did not improve from 0.00132
#
# Epoch 00295: val_loss improved from 0.00132 to 0.00131, saving model to SRCNN_check.h5
#
# Epoch 00296: val_loss did not improve from 0.00131
#
# Epoch 00297: val_loss improved from 0.00131 to 0.00131, saving model to SRCNN_check.h5
#
# Epoch 00298: val_loss did not improve from 0.00131
#
# Epoch 00299: val_loss did not improve from 0.00131
#
# Epoch 00300: val_loss did not improve from 0.00131
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, None, None, 1 0
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 6 640         input_4[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 6 0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 6 36928       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 6 256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 6 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 6 256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 6 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 6 36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 6 256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 6 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 6 36928       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, None, None, 6 256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 6 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 6 36928       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, None, None, 6 256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 6 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 6 36928       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, None, None, 6 256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 6 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 6 36928       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, None, None, 6 256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 6 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 6 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, None, None, 6 256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 6 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 6 36928       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, None, None, 6 256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 6 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 6 36928       activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, None, None, 6 256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 6 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 6 36928       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, None, None, 6 256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 6 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 6 36928       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, None, None, 6 256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 6 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, None, None, 6 36928       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, None, None, 6 256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 6 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, None, None, 6 36928       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, None, None, 6 256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 6 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, None, None, 6 36928       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, None, None, 6 256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 6 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, None, None, 6 36928       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, None, None, 6 256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 6 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, None, None, 6 36928       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, None, None, 6 256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 6 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, None, None, 6 36928       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, None, None, 6 256         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 6 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, None, None, 1 577         activation_19[0][0]
# __________________________________________________________________________________________________
# subtract_1 (Subtract)           (None, None, None, 1 0           input_4[0][0]
#                                                                  conv2d_29[0][0]
# ==================================================================================================
# Total params: 670,529
# Trainable params: 668,225
# Non-trainable params: 2,304
# __________________________________________________________________________________________________
# None
# Epoch 00001: val_loss improved from inf to 0.01002, saving model to DNCNN_check.h5
#
# Epoch 00002: val_loss improved from 0.01002 to 0.00839, saving model to DNCNN_check.h5
#
# Epoch 00003: val_loss improved from 0.00839 to 0.00690, saving model to DNCNN_check.h5
#
# Epoch 00004: val_loss improved from 0.00690 to 0.00526, saving model to DNCNN_check.h5
